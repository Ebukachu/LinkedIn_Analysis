# %%
import pandas as pd

# %%
lnkd_df = pd.read_csv('C:\\Users\\EBUKA\\Connections.csv')
lnkd_df
# Out:
#          First Name         Last Name Email Address            Company  \
# 0         Zachariah          Emmanuel           NaN      Self employed
# 1          Blessing             Lawal           NaN                NaN
# 2         Onyechere       Chukwuemeka           NaN             Upwork
# 3             NGOBI       OWEN ALBERT           NaN           Desishub
# 4             Rafia             Aslam           NaN          YourLogix
# ..              ...               ...           ...                ...
# 98   Oluwafunmilola          Ogunyewo           NaN  Interswitch Group
# 99           Julius         OLAJUMOKE           NaN             MeekFi
# 100            Seth            Samuel           NaN              DevXP
# 101     Onyedikachi          Emmanuel           NaN     Ikeja Electric
# 102           Mercy  Torty, ACA, ACIB           NaN    Access Bank Plc
#
#                                        Position Connected On
# ...
